# %%
#@title Model Selection {run: "auto"}
model_dropdown = "Model2" #@param ["Model1", "Model2"]

if model_dropdown is "Model1":
  # Train with model
  print("You selected", model_dropdown)
else:
  print("Youasd selected", model_dropdown)
# Out:
# Youasd selected Model2
